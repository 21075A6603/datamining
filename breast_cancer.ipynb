# %% [markdown]
# <a href="https://colab.research.google.com/github/21075A6603/datamining/blob/main/breast_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from sklearn.datasets import load_breast_cancer

# %%
data=load_breast_cancer

# %%
data
# Out:
# <function sklearn.datasets._base.load_breast_cancer(*, return_X_y=False, as_frame=False)>

# %%
data=pd.read_csv("/content/breast_cancer.csv")

# %%
data
# Out:
#                                                                                                                                                                                                             569  \
# 17.99 10.38 122.80 1001.0 0.11840 0.27760 0.30010 0.14710 0.2419 0.07871 1.0950 0.9053 8.589 153.40 0.006399 0.04904 0.05373 0.01587 0.03003 0.006193 25.380 17.33 184.60 2019.0 0.16220 0.66560 0.7119  0.2654
# 20.57 17.77 132.90 1326.0 0.08474 0.07864 0.08690 0.07017 0.1812 0.05667 0.5435 0.7339 3.398 74.08  0.005225 0.01308 0.01860 0.01340 0.01389 0.003532 24.990 23.41 158.80 1956.0 0.12380 0.18660 0.2416  0.1860
# 19.69 21.25 130.00 1203.0 0.10960 0.15990 0.19740 0.12790 0.2069 0.05999 0.7456 0.7869 4.585 94.03  0.006150 0.04006 0.03832 0.02058 0.02250 0.004571 23.570 25.53 152.50 1709.0 0.14440 0.42450 0.4504  0.2430
# ...

# %%
data=data.iloc[:,:-1]

# %%
data
# Out:
#                                                                                                                                                                                                             569  \
# 17.99 10.38 122.80 1001.0 0.11840 0.27760 0.30010 0.14710 0.2419 0.07871 1.0950 0.9053 8.589 153.40 0.006399 0.04904 0.05373 0.01587 0.03003 0.006193 25.380 17.33 184.60 2019.0 0.16220 0.66560 0.7119  0.2654
# 20.57 17.77 132.90 1326.0 0.08474 0.07864 0.08690 0.07017 0.1812 0.05667 0.5435 0.7339 3.398 74.08  0.005225 0.01308 0.01860 0.01340 0.01389 0.003532 24.990 23.41 158.80 1956.0 0.12380 0.18660 0.2416  0.1860
# 19.69 21.25 130.00 1203.0 0.10960 0.15990 0.19740 0.12790 0.2069 0.05999 0.7456 0.7869 4.585 94.03  0.006150 0.04006 0.03832 0.02058 0.02250 0.004571 23.570 25.53 152.50 1709.0 0.14440 0.42450 0.4504  0.2430
# ...

# %%
data=data.iloc[:,1:]

# %%
data
# Out:
#                                                                                                                                                                                                              30  \
# 17.99 10.38 122.80 1001.0 0.11840 0.27760 0.30010 0.14710 0.2419 0.07871 1.0950 0.9053 8.589 153.40 0.006399 0.04904 0.05373 0.01587 0.03003 0.006193 25.380 17.33 184.60 2019.0 0.16220 0.66560 0.7119  0.4601
# 20.57 17.77 132.90 1326.0 0.08474 0.07864 0.08690 0.07017 0.1812 0.05667 0.5435 0.7339 3.398 74.08  0.005225 0.01308 0.01860 0.01340 0.01389 0.003532 24.990 23.41 158.80 1956.0 0.12380 0.18660 0.2416  0.2750
# 19.69 21.25 130.00 1203.0 0.10960 0.15990 0.19740 0.12790 0.2069 0.05999 0.7456 0.7869 4.585 94.03  0.006150 0.04006 0.03832 0.02058 0.02250 0.004571 23.570 25.53 152.50 1709.0 0.14440 0.42450 0.4504  0.3613
# ...

# %%
data.columns
# Out:
# Index(['30', 'malignant'], dtype='object')

# %%
data['malignant']
# Out:
# 17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010  0.14710  0.2419  0.07871  1.0950  0.9053  8.589  153.40  0.006399  0.04904  0.05373  0.01587  0.03003  0.006193  25.380  17.33  184.60  2019.0  0.16220  0.66560  0.7119    0.11890
# 20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690  0.07017  0.1812  0.05667  0.5435  0.7339  3.398  74.08   0.005225  0.01308  0.01860  0.01340  0.01389  0.003532  24.990  23.41  158.80  1956.0  0.12380  0.18660  0.2416    0.08902
# 19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740  0.12790  0.2069  0.05999  0.7456  0.7869  4.585  94.03   0.006150  0.04006  0.03832  0.02058  0.02250  0.004571  23.570  25.53  152.50  1709.0  0.14440  0.42450  0.4504    0.08758
# 11.42  20.38  77.58   386.1   0.14250  0.28390  0.24140  0.10520  0.2597  0.09744  0.4956  1.1560  3.445  27.23   0.009110  0.07458  0.05661  0.01867  0.05963  0.009208  14.910  26.50  98.87   567.7   0.20980  0.86630  0.6869    0.17300
# ...

# %%
data.info
# Out:
# <bound method Series.info of 17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010  0.14710  0.2419  0.07871  1.0950  0.9053  8.589  153.40  0.006399  0.04904  0.05373  0.01587  0.03003  0.006193  25.380  17.33  184.60  2019.0  0.16220  0.66560  0.7119    0.11890
# 20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690  0.07017  0.1812  0.05667  0.5435  0.7339  3.398  74.08   0.005225  0.01308  0.01860  0.01340  0.01389  0.003532  24.990  23.41  158.80  1956.0  0.12380  0.18660  0.2416    0.08902
# 19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740  0.12790  0.2069  0.05999  0.7456  0.7869  4.585  94.03   0.006150  0.04006  0.03832  0.02058  0.02250  0.004571  23.570  25.53  152.50  1709.0  0.14440  0.42450  0.4504    0.08758
# 11.42  20.38  77.58   386.1   0.14250  0.28390  0.24140  0.10520  0.2597  0.09744  0.4956  1.1560  3.445  27.23   0.009110  0.07458  0.05661  0.01867  0.05963  0.009208  14.910  26.50  98.87   567.7   0.20980  0.86630  0.6869    0.17300
# ...

# %%
from sklearn.neural_network import MLPClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.datasets import load_iris
iris=load_iris()

# %%
data=iris.data

# %%
target=iris.target_names

# %%
target = pd.get_dummies(iris['target'])

# %%
target
# Out:
#      0  1  2
# 0    1  0  0
# 1    1  0  0
# 2    1  0  0
# 3    1  0  0
# 4    1  0  0
# ..  .. .. ..
# 145  0  0  1
# 146  0  0  1
# 147  0  0  1
# 148  0  0  1
# 149  0  0  1
#
# [150 rows x 3 columns]

# %%
target = pd.get_dummies(iris['target'])

# %%
target
# Out:
#      0  1  2
# 0    1  0  0
# 1    1  0  0
# 2    1  0  0
# 3    1  0  0
# 4    1  0  0
# ..  .. .. ..
# 145  0  0  1
# 146  0  0  1
# 147  0  0  1
# 148  0  0  1
# 149  0  0  1
#
# [150 rows x 3 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
data = MinMaxScaler().fit_transform(data)

# %%
data.shape
# Out:
# (150, 4)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train,x_test,y_train,y_test=train_test_split(data,target,test_size=0.3,random_state=42,stratify=target)

# %%
def MLP():
  model=Sequential()
  model.add(Dense(8,input_shape=(4,)))
  model.add(Dense(16,activation='relu'))
  model.add(Dense(8,activation='relu'))
  model.add(Dense(3,activation='softmax'))
  return model
model=MLP()
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 8)                 40
#
#  dense_7 (Dense)             (None, 16)                144
#
#  dense_8 (Dense)             (None, 8)                 136
#
#  dense_9 (Dense)             (None, 3)                 27
#
# ...
# Total params: 347
# Trainable params: 347
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 1s 4ms/step - loss: 0.9662 - accuracy: 0.6667
# Epoch 2/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9426 - accuracy: 0.6667
# Epoch 3/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9216 - accuracy: 0.6667
# Epoch 4/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9031 - accuracy: 0.6667
# Epoch 5/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8855 - accuracy: 0.6667
# Epoch 6/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8683 - accuracy: 0.6667
# Epoch 7/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8514 - accuracy: 0.6667
# Epoch 8/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8351 - accuracy: 0.6667
# Epoch 9/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8185 - accuracy: 0.6667
# Epoch 10/50
# ...

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print(f'Test Accuracy:{test_acc}')
print(f'Test Loss:{test_loss}')
# Out:
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3518 - accuracy: 0.9556
# Test Accuracy:0.9555555582046509
# Test Loss:0.35176122188568115

# %%
def SLP():
  model = Sequential()
# create a single layer of input layer [features.shape[1] no of neurons] and output layer with [1] neuron
  model.add(Dense(1, input_shape = (data.shape[1],)))
  return model
model = SLP()

# %%
model.compile(optimizer='sgd',loss='binary_crossentropy',metrics=['acccuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_5 (Dense)             (None, 1)                 5
#
# ...
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4555 - accuracy: 0.7238
