# %% [markdown]
# <a href="https://colab.research.google.com/github/21075A6603/datamining/blob/main/london_bostan_housung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/Housing+Data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13549 entries, 0 to 13548
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           13549 non-null  object
#  1   area           13549 non-null  object
#  2   average_price  13549 non-null  int64
#  3   code           13549 non-null  object
#  4   houses_sold    13455 non-null  float64
#  5   no_of_crimes   7439 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 635.2+ KB

# %%
data.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#showing the null values in the visual manner:
sns.heatmap(data.isnull())
plt.show()

# %%
#changing the data tyoe od the data (objetc) to date time:
data.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
data.date=pd.to_datetime(data.date)

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %%
data.date
# Out:
# 0       1995-01-01
# 1       1995-02-01
# 2       1995-03-01
# 3       1995-04-01
# 4       1995-05-01
#            ...
# 13544   2019-09-01
# 13545   2019-10-01
# 13546   2019-11-01
# 13547   2019-12-01
# 13548   2020-01-01
# Name: date, Length: 13549, dtype: datetime64[ns]

# %%
#adding ht eyear column in the dataframe which containing only the year:
data['year']=data.date.dt.year

# %%
data['year']
# Out:
# 0        1995
# 1        1995
# 2        1995
# 3        1995
# 4        1995
#          ...
# 13544    2019
# 13545    2019
# 13546    2019
# 13547    2019
# 13548    2020
# Name: year, Length: 13549, dtype: int64

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
data['month']=data.date.dt.month

# %%
data.month
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#          ..
# 13544     9
# 13545    10
# 13546    11
# 13547    12
# 13548     1
# Name: month, Length: 13549, dtype: int64

# %%
data.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year  month
# 0           NaN  1995      1
# 1           NaN  1995      2
# 2           NaN  1995      3
# 3           NaN  1995      4
# 4           NaN  1995      5

# %%
data=data.drop(['year','month'],axis=1,inplace=True)

# %%
data.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
data[data.no_of_crimes==0]
# Out:
#           date            area  average_price       code  houses_sold  \
# 72    1/1/2001  city of london         284262  E09000001         24.0
# 73    2/1/2001  city of london         198137  E09000001         37.0
# 74    3/1/2001  city of london         189033  E09000001         44.0
# 75    4/1/2001  city of london         205494  E09000001         38.0
# 76    5/1/2001  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178  11/1/2009  city of london         397909  E09000001         11.0
# 179  12/1/2009  city of london         411955  E09000001         16.0
# 180   1/1/2010  city of london         464436  E09000001         20.0
# 181   2/1/2010  city of london         490525  E09000001          9.0
# 182   3/1/2010  city of london         498241  E09000001         15.0
#
#      no_of_crimes
# 72            0.0
# 73            0.0
# 74            0.0
# 75            0.0
# 76            0.0
# ...

# %%
len(data[data.no_of_crimes==0])
# Out:
# 104

# %%
#render the max area of england per year:
df1=data[data.area=='england']

# %%
data.date=pd.to_datetime(data.date)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13549 entries, 0 to 13548
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           13549 non-null  datetime64[ns]
#  1   area           13549 non-null  object
#  2   average_price  13549 non-null  int64
#  3   code           13549 non-null  object
#  4   houses_sold    13455 non-null  float64
#  5   no_of_crimes   7439 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 635.2+ KB

# %%
data.insert(3,'year',data.date.dt.year)

# %%
data.head()
# Out:
#         date            area  average_price  year       code  houses_sold  \
# 0 1995-01-01  city of london          91449  1995  E09000001         17.0
# 1 1995-02-01  city of london          82203  1995  E09000001          7.0
# 2 1995-03-01  city of london          79121  1995  E09000001         14.0
# 3 1995-04-01  city of london          77101  1995  E09000001          7.0
# 4 1995-05-01  city of london          84409  1995  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
data.drop(['year'],inplace=True,axis=1)

# %%
data.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
data.insert(2,'year',data.date.dt.year)

# %%
data.head()
# Out:
#         date            area  year  average_price       code  houses_sold  \
# 0 1995-01-01  city of london  1995          91449  E09000001         17.0
# 1 1995-02-01  city of london  1995          82203  E09000001          7.0
# 2 1995-03-01  city of london  1995          79121  E09000001         14.0
# 3 1995-04-01  city of london  1995          77101  E09000001          7.0
# 4 1995-05-01  city of london  1995          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df1
# Out:
#             date     area  average_price       code  houses_sold  no_of_crimes
# 13248   1/1/1995  england          53203  E92000001      47639.0           NaN
# 13249   2/1/1995  england          53096  E92000001      47880.0           NaN
# 13250   3/1/1995  england          53201  E92000001      67025.0           NaN
# 13251   4/1/1995  england          53591  E92000001      56925.0           NaN
# 13252   5/1/1995  england          53678  E92000001      64192.0           NaN
# ...          ...      ...            ...        ...          ...           ...
# 13544   9/1/2019  england         249942  E92000001      64605.0           NaN
# 13545  10/1/2019  england         249376  E92000001      68677.0           NaN
# 13546  11/1/2019  england         248515  E92000001      67814.0           NaN
# 13547  12/1/2019  england         250410  E92000001          NaN           NaN
# 13548   1/1/2020  england         247355  E92000001          NaN           NaN
#
# [301 rows x 6 columns]

# %%
data.groupby('year').average_price.min()
# Out:
# year
# 1995     41688
# 1996     40722
# 1997     42353
# 1998     43510
# 1999     43969
# 2000     47604
# 2001     49045
# 2002     54746
# 2003     67520
# 2004     88520
# 2005    110454
# 2006    121124
# 2007    131175
# 2008    120275
# 2009    117079
# 2010    119688
# 2011    115328
# 2012    113011
# 2013    112008
# 2014    114531
# 2015    117156
# 2016    121085
# 2017    121858
# 2018    124038
# 2019    124567
# 2020    126592
# Name: average_price, dtype: int64

# %%
data.groupby('year').average_price.max()
# Out:
# year
# 1995     200722
# 1996     223197
# 1997     265112
# 1998     277600
# 1999     354241
# 2000     397353
# 2001     451028
# 2002     497538
# 2003     488704
# 2004     559286
# 2005     555847
# 2006     644541
# 2007     830950
# 2008     832753
# 2009     782459
# 2010     884674
# 2011     959520
# 2012    1077366
# 2013    1217729
# 2014    1365050
# 2015    1353679
# 2016    1357231
# 2017    1412255
# 2018    1463378
# 2019    1294113
# 2020    1178166
# Name: average_price, dtype: int64

# %%
data.groupby('year').average_price.mean()
# Out:
# year
# 1995     75880.235185
# 1996     78875.274908
# 1997     89618.350000
# 1998    101747.073801
# 1999    114256.172222
# 2000    139979.442593
# 2001    156932.355556
# 2002    182190.731481
# 2003    205099.553704
# 2004    224604.720370
# 2005    233314.512963
# 2006    249303.109259
# 2007    285944.279630
# 2008    287478.972222
# 2009    259296.896296
# 2010    287559.164815
# 2011    294819.138889
# 2012    309409.501852
# 2013    334589.564815
# 2014    388208.392593
# 2015    421356.100000
# 2016    454884.461111
# 2017    469978.938889
# 2018    467240.674074
# 2019    460056.659259
# 2020    463329.977778
# Name: average_price, dtype: float64

# %%
#what is the max and min number of crimes per area:
data.head(2)
# Out:
#         date            area  year  average_price       code  houses_sold  \
# 0 1995-01-01  city of london  1995          91449  E09000001         17.0
# 1 1995-02-01  city of london  1995          82203  E09000001          7.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN

# %%
data.no_of_crimes
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 13544   NaN
# 13545   NaN
# 13546   NaN
# 13547   NaN
# 13548   NaN
# Name: no_of_crimes, Length: 13549, dtype: float64

# %%
df1=data.groupby('area').no_of_crimes.min().sort_values()
df1
# Out:
# area
# city of london               0.0
# kingston upon thames       692.0
# richmond upon thames       700.0
# sutton                     787.0
# merton                     819.0
# bexley                     860.0
# harrow                     937.0
# havering                  1130.0
# barking and dagenham      1217.0
# hammersmith and fulham    1323.0
# kensington and chelsea    1347.0
# bromley                   1441.0
# hillingdon                1445.0
# redbridge                 1487.0
# greenwich                 1513.0
# hounslow                  1529.0
# haringey                  1536.0
# waltham forest            1575.0
# wandsworth                1582.0
# enfield                   1635.0
# tower hamlets             1646.0
# lewisham                  1675.0
# barnet                    1703.0
# brent                     1850.0
# hackney                   1870.0
# ealing                    1871.0
# islington                 1871.0
# croydon                   2031.0
# ...

# %%
df1=pd.DataFrame(df1)

# %%
sns.heatmap(df1)
plt.show()

# %%
sns.distplot(df1)
# Out:
# <ipython-input-92-d71e32e36f5e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1)
# <Axes: ylabel='Density'>

# %%
df2=data.groupby('area').no_of_crimes.max()
df2
# Out:
# area
# barking and dagenham      2049.0
# barnet                    2893.0
# bexley                    1914.0
# brent                     2937.0
# bromley                   2637.0
# camden                    4558.0
# city of london              10.0
# croydon                   3263.0
# ealing                    3401.0
# east midlands                NaN
# east of england              NaN
# enfield                   2798.0
# england                      NaN
# greenwich                 2853.0
# hackney                   3466.0
# hammersmith and fulham    2645.0
# haringey                  3199.0
# harrow                    1763.0
# havering                  1956.0
# hillingdon                2819.0
# hounslow                  2817.0
# inner london                 NaN
# islington                 3384.0
# kensington and chelsea    2778.0
# kingston upon thames      1379.0
# lambeth                   4701.0
# lewisham                  2813.0
# london                       NaN
# ...

# %%
sns.displot(df2)

# %%
#show the toatal count of records each area,where average price is less then 100000
data.head(2)
# Out:
#         date            area  year  average_price       code  houses_sold  \
# 0 1995-01-01  city of london  1995          91449  E09000001         17.0
# 1 1995-02-01  city of london  1995          82203  E09000001          7.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN

# %%
data[data.average_price<100000].area.value_counts()
# Out:
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...
