# %%
import pandas as pd

# %%
###kind of data that pandas as handle:

# %%
#iserted the student data to the datafraem:
df=pd.DataFrame(
        {
                "Name":["azar","ameer","asshu"],
                "age":[22,20,21],
                "grade":[16,14,16]
                
        }
)
df
# Out:
#     Name  age  grade
# 0   azar   22     16
# 1  ameer   20     14
# 2  asshu   21     16

# %%
#adding columns to the dataframe:
sex=["male","male","female"]
df["Sex"]="sex"

# %%
df
# Out:
#     Name  age  grade  Sex
# 0   azar   22     16  sex
# 1  ameer   20     14  sex
# 2  asshu   21     16  sex

# %%
#position at wehre we want to insert into the dataframe:
df.insert(3,"address",["mlg","hyd","wlg"],True)
df
# Out:
#     Name  age  G_yeear address  grade
# 0   azar   22     2024     mlg     16
# 1  ameer   20     2026     hyd     14
# 2  asshu   21     2023     wlg     16

# %%
df.insert(2,"G_yeear",[2024,2026,2023],True)
df
# Out:
#     Name  age  G_yeear  grade
# 0   azar   22     2024     16
# 1  ameer   20     2026     14
# 2  asshu   21     2023     16

# %%
#recallin gthe manual insertion of the dataframe:
cgpa=[8.5,9.6,9]
df['CGPA']=cgpa
print (df)
# Out:
#     Name  age address address  G_yeear  grade  Sex  CGPA
# 0   azar   22     mlg     mlg     2024     16  sex   8.5
# 1  ameer   20     hyd     hyd     2026     14  sex   9.6
# 2  asshu   21     wlg     wlg     2023     16  sex   9.0

# %%
ages=df['age']
print(ages.dtype)
# Out:
# int64

# %%
df.drop(['address'],axis=1)
df
# Out:
#     Name  age address address address  G_yeear  grade  Sex  CGPA
# 0   azar   22     mlg     mlg     mlg     2024     16  sex   8.5
# 1  ameer   20     hyd     hyd     hyd     2026     14  sex   9.6
# 2  asshu   21     wlg     wlg     wlg     2023     16  sex   9.0

# %%
df.describe()
# Out:
#         age      G_yeear      grade      CGPA
# count   3.0     3.000000   3.000000  3.000000
# mean   21.0  2024.333333  15.333333  9.033333
# std     1.0     1.527525   1.154701  0.550757
# min    20.0  2023.000000  14.000000  8.500000
# 25%    20.5  2023.500000  15.000000  8.750000
# 50%    21.0  2024.000000  16.000000  9.000000
# 75%    21.5  2025.000000  16.000000  9.300000
# max    22.0  2026.000000  16.000000  9.600000

# %%
df.isnull()
# Out:
#     Name    age  address  address  address  G_yeear  grade    Sex   CGPA
# 0  False  False    False    False    False    False  False  False  False
# 1  False  False    False    False    False    False  False  False  False
# 2  False  False    False    False    False    False  False  False  False

# %%
df.notnull()
# Out:
#    Name   age  address  address  address  G_yeear  grade   Sex  CGPA
# 0  True  True     True     True     True     True   True  True  True
# 1  True  True     True     True     True     True   True  True  True
# 2  True  True     True     True     True     True   True  True  True

# %%
df.columns
# Out:
# Index(['Name', 'age', 'G_yeear', 'address', 'grade'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   age      3 non-null      int64
#  2   G_yeear  3 non-null      int64
#  3   address  3 non-null      object
#  4   grade    3 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 248.0+ bytes

# %%
df2=pd.DataFrame(
        {
                'Name':['alex','ram','raj'],
                'age':[19,20,24],
                'G_year':[2023,2024,2025],
                'address':['hyd','hnk','kphb'],
                'grade':[17,16,15]
        }
)
df2
# Out:
#    Name  age  G_year address  grade
# 0  alex   19    2023     hyd     17
# 1   ram   20    2024     hnk     16
# 2   raj   24    2025    kphb     15

# %%
df = pd.concat([df, df2], axis=0)

# %%
df
# Out:
#     Name  age  G_yeear address  grade  G_year
# 0   azar   22   2024.0     mlg     16     NaN
# 1  ameer   20   2026.0     hyd     14     NaN
# 2  asshu   21   2023.0     wlg     16     NaN
# 0   alex   19      NaN     hyd     17  2023.0
# 1    ram   20      NaN     hnk     16  2024.0
# 2    raj   24      NaN    kphb     15  2025.0

# %%
df2
# Out:
#    Name  age  G_year address  grade
# 0  alex   19    2023     hyd     17
# 1   ram   20    2024     hnk     16
# 2   raj   24    2025    kphb     15

# %%
max(df['age'])
# Out:
# 24

# %%
min(df['G_year'])
# Out:
# nan

# %%
df.describe()
# it can take only numerical data:
# Out:
#              age      G_yeear      grade  G_year
# count   6.000000     3.000000   6.000000     3.0
# mean   21.000000  2024.333333  15.666667  2024.0
# std     1.788854     1.527525   1.032796     1.0
# min    19.000000  2023.000000  14.000000  2023.0
# 25%    20.000000  2023.500000  15.250000  2023.5
# 50%    20.500000  2024.000000  16.000000  2024.0
# 75%    21.750000  2025.000000  16.000000  2024.5
# max    24.000000  2026.000000  17.000000  2025.0

# %%
data=pd.read_excel('superstore.xls')
df=pd.DataFrame(data)
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520  \
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...
# 0      Claire Gute   Consumer  United States        Henderson  ...  \
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Row ID        Order ID Order Date  Ship Date       Ship Mode
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class  \
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')
