# %% [markdown]
# <a href="https://colab.research.google.com/github/21075A6603/datamining/blob/main/uProject_2_car_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/Project+2+-+Cars+Dataset.csv')

# %%
data.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
data.shape
# Out:
# (432, 15)

# %%
# check for null values:
data.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
# fill the null values with the appropriate:
data['Model'].fillna('unknown',inplace=True)

# %%
data.isnull().sum()
# Out:
# Make           4
# Model          0
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
data.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
data['Type'].fillna('unknown',inplace=True)
data['DriveTrain'].fillna('unknown',inplace=True)
data['Origin'].fillna('unknown',inplace=True)
data['MSRP'].fillna('unknown',inplace=True)
data['Invoice'].fillna('unknown',inplace=True)

# %%
data.isnull().sum()
# Out:
# Make           4
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
data['Wheelbase'][[2,10]]
# Out:
# 2     105.0
# 10    104.0
# Name: Wheelbase, dtype: float64

# %%
data['EngineSize'].fillna(data['EngineSize'].mean(),inplace=True)

# %%
data['MPG_City'].fillna(data['MPG_City'].mean(),inplace=True)

# %%
data['MPG_Highway'].fillna(data['MPG_Highway'].mean(),inplace=True)

# %%
data['Weight'].fillna(data['Weight'].mean(),inplace=True)

# %%
data['Wheelbase'].fillna(data['Wheelbase'].mean(),inplace=True)
data['Length'].fillna(data['Length'].mean(),inplace=True)
data['Horsepower'].fillna(data['Horsepower'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Make           4
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      6
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
data['Cylinders'].fillna(data['Cylinders'].mean(),inplace=True)

# %%
data['Cylinders']
# Out:
# 0      6.0
# 1      4.0
# 2      4.0
# 3      6.0
# 4      6.0
#       ...
# 427    5.0
# 428    5.0
# 429    6.0
# 430    4.0
# 431    5.0
# Name: Cylinders, Length: 432, dtype: float64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
data['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
data.Origin
# Out:
# 0        Asia
# 1        Asia
# 2        Asia
# 3        Asia
# 4        Asia
#         ...
# 427    Europe
# 428    Europe
# 429    Europe
# 430    Europe
# 431    Europe
# Name: Origin, Length: 428, dtype: object

# %%
# data[(data['Origin']=='Asia') | (Data['Origin']=='Europe')]
data[data['Origin'].isin(['Aisa','Europe'])]
# Out:
#       Make                      Model   Type  Origin DriveTrain      MSRP  \
# 7     Audi                A4 1.8T 4dr  Sedan  Europe      Front  $25,940
# 8     Audi     A41.8T convertible 2dr  Sedan  Europe      Front  $35,940
# 9     Audi                 A4 3.0 4dr  Sedan  Europe      Front  $31,840
# 10    Audi  A4 3.0 Quattro 4dr manual  Sedan  Europe        All  $33,430
# 11    Audi    A4 3.0 Quattro 4dr auto  Sedan  Europe        All  $34,480
# ..     ...                        ...    ...     ...        ...       ...
# 427  Volvo    C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo    C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo                 S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                        V40  Wagon  Europe      Front  $26,135
# 431  Volvo                       XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
#remove the records which weights's atribute is greater then 4000
data[~(data['Weight']>4000)]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data.shape
# Out:
# (428, 15)

# %%
# do some opearations using the lambda function:

# %%
data['MPG_City']=data['MPG_City'].apply(lambda x:x+5)

# %%
data.MPG_City
# Out:
# 0      22.0
# 1      29.0
# 2      27.0
# 3      25.0
# 4      23.0
#        ...
# 427    26.0
# 428    25.0
# 429    24.0
# 430    27.0
# 431    25.0
# Name: MPG_City, Length: 428, dtype: float64
